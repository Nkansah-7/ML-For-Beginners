# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
X, y = datasets.load_linnerud(return_X_y=True)
print(X.shape)
print(X[0])
print(y.shape)
print(y[0])
# Out:
# (20, 3)
# [  5. 162.  60.]
# (20, 3)
# [191.  36.  50.]

# %%
X = X[:, 0]
X = X.reshape((-1,1))
print(X.shape)
y = y[:,0]
# Out:
# (20, 1)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Creating predictions using test data
y_pred = model.predict(X_test)

# %%
#Creating a scattlerplot
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='red', linewidth=3)
plt.xlabel('Number of chins')
plt.ylabel('Weight(pounds)')
plt.title('A Graph Plot Showing How Chins affect weight')
plt.show()

# %%
X, y = datasets.load_linnerud(return_X_y=True)
print(X.shape)
print(X[0])

print(y.shape)
print(y[0])
# Out:
# (20, 3)
# [  5. 162.  60.]
# (20, 3)
# [191.  36.  50.]

# %%
X = X[:, 1]
X = X.reshape((-1,1))
print(X.shape)
y = y[:,1]
# Out:
# (20, 1)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3)

# %%
model = linear_model.LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, color = 'black')
plt.plot(X_test, y_pred, color = 'blue')
plt.xlabel("Number of Situps")
plt.ylabel("Waistline (inches)")
plt.title("A graph plot showing number of sitpus against waist size")
plt.show()

# %%
X,y = datasets.load_linnerud(return_X_y=True)

print(X.shape)
print(X[0])
print(y.shape)
print(y[0])
# Out:
# (20, 3)
# [  5. 162.  60.]
# (20, 3)
# [191.  36.  50.]

# %%
X = X[:, 2]
X = X.reshape((-1,1))
print(X.shape)
y = y[:,2]
# Out:
# (20, 1)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3)

# %%
model = linear_model.LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, color = 'black')
plt.plot(X_test, y_pred, color = 'blue')
plt.xlabel("Number of jumps")
plt.ylabel("pulse()")
plt.title("A graph plot showing number of sitpus against waist size")
plt.show()
